# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

sys.path.append(os.path.join(os.getcwd(), ".."))
from plotting_tools import *

# %%
df = pd.read_csv("rain.txt", decimal=",", sep=";", header=None, skiprows=1).reset_index()
df.columns = ["date", "rain"]
df['date'] = pd.date_range(start="2020-03-01 00:00", periods=len(df), freq="5min")

# %%
df.describe()
# Out:
#                       date          rain
# count                25659  25659.000000
# mean   2020-04-14 13:05:00      0.213959
# min    2020-03-01 00:00:00      0.000000
# 25%    2020-03-23 06:32:30      0.000000
# 50%    2020-04-14 13:05:00      0.000000
# 75%    2020-05-06 19:37:30      0.000000
# max    2020-05-29 02:10:00     84.333000
# std                    NaN      1.661015

# %%
fig, ax = plt.subplots(figsize=(14, 3.5))
sns.lineplot(data=df, x="date", y="rain", ax=ax)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%d.%m."))  # Format without year
plt.tight_layout()
plt.ylim(0,90)
plt.ylabel("Precipitation [mm]")
plt.xlabel("Date")
plt.show()
plt.savefig("../../plots/rain.png")
